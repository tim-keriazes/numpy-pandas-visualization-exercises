# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data

# %%
# data('mpg', show_doc=True) # view the documentation for the dataset
mpg = data('mpg') # load the dataset and store it in a variable

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
df['passing_english']= df.english >= 70
#new colomn, if greater than 70 indicate true

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
df.sort_values(by='passing_english')
#sort by passing english, looks like duplicates are handled by ascending order of key
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %%
df.sort_values(by=['passing_english','name'])
#sort by english then name
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
df.sort_values(by=['passing_english','english'])
#sort by passing_english then english
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df['overall_grade']=(df.math+df.english+df.reading)/3
#new column with inputs being the mean of the values

# %%
df.sort_values(by='name')
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 4       Ada    77       92       98             True      89.000000
# 11     Alan    92       62       72            False      75.333333
# 8    Albert    92       62       87            False      80.333333
# 3     Billy    98       96       88             True      94.000000
# 10    Isaac    92       99       93             True      94.666667
# 1      Jane    88       79       67             True      78.000000
# 5      John    79       76       93             True      82.666667
# 7     Marie    93       63       90            False      82.000000
# 9   Richard    69       80       94             True      81.000000
# 0     Sally    62       85       80             True      75.666667
# 2     Suzie    94       74       95             True      87.666667
# 6    Thomas    82       64       81            False      75.666667

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg
#234 rows and 11 columns
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.info()
#shows datatype for the columns with .info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
##shows summary with .describe
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.rename(columns={'cty':'city'},inplace = True)
#renamed cty column to city

# %%
mpg.rename(columns={'hwy':'highway'},inplace = True)
#renamed hwy column to highway
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
mpg.sort_values(by=['city','highway'])
#looks like no cars hav better city than hwy
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  city  \
# 55         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60         dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 127         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4     9
# ..           ...                  ...    ...   ...  ...         ...  ..   ...
# 100        honda                civic    1.6  1999    4  manual(m5)   f    28
# 197       toyota              corolla    1.8  2008    4  manual(m5)   f    28
# 223   volkswagen           new beetle    1.9  1999    4    auto(l4)   f    29
# 213   volkswagen                jetta    1.9  1999    4  manual(m5)   f    33
# 222   volkswagen           new beetle    1.9  1999    4  manual(m5)   f    35
#
#      highway fl       class
# ...

# %%
mpg['mileage_difference']=(mpg.highway-mpg.city)
mpg.sort_values(by='mileage_difference')
#new column
#highest mileage difference is the the 2008 honda civic 1.8l with 12mpg diff
#how can i call that particular
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 85          ford    f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 30     chevrolet    k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4    11
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 106        honda              civic    1.8  2008    4    auto(l5)   f    25
# 213   volkswagen              jetta    1.9  1999    4  manual(m5)   f    33
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
#
# ...

# %%
mpg[mpg['class'] == 'compact'].sort_values(by='highway')
#highest highway mpg volkswagen	jetta	2.8	1999
#lowest volkswagen	jetta	1.9	1999	4	manual(m5)
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 220   volkswagen         jetta    2.8  1999    6    auto(l4)   f    16
# 221   volkswagen         jetta    2.8  1999    6  manual(m5)   f    17
# 212   volkswagen           gti    2.8  1999    6  manual(m5)   f    17
# 172       subaru   impreza awd    2.5  2008    4  manual(m5)   4    19
# 170       subaru   impreza awd    2.5  2008    4    auto(s4)   4    20
# 15          audi    a4 quattro    3.1  2008    6  manual(m6)   4    15
# 14          audi    a4 quattro    3.1  2008    6    auto(s6)   4    17
# 13          audi    a4 quattro    2.8  1999    6  manual(m5)   4    17
# 9           audi    a4 quattro    1.8  1999    4    auto(l5)   4    16
# 12          audi    a4 quattro    2.8  1999    6    auto(l5)   4    15
# 209   volkswagen           gti    2.0  1999    4    auto(l4)   f    19
# 215   volkswagen         jetta    2.0  1999    4    auto(l4)   f    19
# ...

# %%
mpg[mpg['class'] == 'compact'].sort_values(by='highway').nsmallest(1, 'highway')
#smallest
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %%
mpg[mpg['class'] == 'compact'].sort_values(by='highway').nlargest(1, 'highway')
#slargest
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference
# 213  compact                  11

# %%
mpg['avg_mileage']=(mpg.city+mpg.highway)/2
mpg
#new column, avg mileage
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
mpg[mpg.manufacturer == 'dodge'].sort_values(by='avg_mileage').nsmallest(1,'avg_mileage')
#lowest avg mileage
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  avg_mileage
# 70       12  e  pickup                   3         10.5

# %%
mpg[mpg.manufacturer == 'dodge'].sort_values(by='avg_mileage').nlargest(1,'avg_mileage')
#highest avg mileage
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_difference  avg_mileage
# 38  r  minivan                   6         21.0

# %%
mammals = data ('Mammals', show_doc=True)
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
mammals.info()
#107 rows, 4 columns
#float and bool data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
mammals.sort_values(by='speed').tail(n=1)
#weight is 55
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %%
mammals[mammals.specials].shape
#10 rows of specials out of 107, 9.34%
# Out:
# (10, 4)

# %%
mammals[mammals.specials]
# Out:
#      weight  speed  hoppers  specials
# 10   3800.0   25.0    False      True
# 59     12.0   24.0    False      True
# 60     11.0   30.0    False      True
# 65      5.0   27.0    False      True
# 66      3.0   16.0    False      True
# 68     70.0   40.0    False      True
# 69     13.0   37.0    False      True
# 70      9.0    3.2    False      True
# 105     5.0    7.4    False      True
# 107     4.0    1.6    False      True

# %%
mammals.speed.median()
# Out:
# 48.0

# %%
mammals[(mammals.speed>48) &(mammals['hoppers']) ].count()
#checked for median speed, used boolean mask for speed greater than median and also a hopper returned a count of that data frame
# Out:
# weight      7
# speed       7
# hoppers     7
# specials    7
# dtype: int64

# %%
# mpg.loc[mpg['class'] == 'compact', 'is_compact'] = True
# mpg.loc[mpg['class'] != 'compact', 'is_compact'] = False

# %%
# mpg.mileage_difference.nlargest(n=1, keep='all')

# %%
# mpg[mask].sort_values(by = 'average_mileage').nsmallest(1, 'average_mileage')
